# %%
#IMPORTY
#Pro SQLalchemy
from sqlalchemy import Column, Integer, String, BigInteger, ForeignKey
from sqlalchemy import create_engine
from sqlalchemy.orm import relationship, sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy_utils.functions import database_exists, create_database

#IMPORTY
#Pro graphQL
import uvicorn
import graphene

from fastapi import FastAPI
from multiprocessing import Process
from starlette_graphene3 import GraphQLApp, make_graphiql_handler

#Pro web
from fastapi.middleware.cors import CORSMiddleware

# %%
#ENGINE
connectionString = 'postgresql+psycopg2://postgres:example@postgres/D-filmy'

if not database_exists(connectionString):   #=> False
    try:
        create_database(connectionString)
        doCreateAll = True
        print('Database created')
    
    except Exception as e:
        print('Database does not exists and cannot be created')
        raise

else:
    print('Database already exists')

engine = create_engine(connectionString)
# Out:
# Database already exists

# %%
#MODELY
BaseModel = declarative_base()

#Žánr
class ZanrModel(BaseModel):
    __tablename__ = 'zanry'

    #Atributy
    id = Column(BigInteger, primary_key = True)
    nazev = Column(String)

    #Vztahy
    filmZanr = relationship('FilmZanrModel', back_populates = 'zanr')

#Stav
class StavModel(BaseModel):
    __tablename__ = 'stavy'

    #Atributy
    id = Column(BigInteger, primary_key = True)
    nazev = Column(String)

    #Vztahy
    filmy = relationship('FilmModel', back_populates = 'stav')

#Film
class FilmModel(BaseModel):
    __tablename__ = 'filmy'

    #Atributy
    id = Column(BigInteger, primary_key = True)
    nazev = Column(String)
    rok = Column(Integer)
    zeme = Column(String)
    delka = Column(String)
    stav_id = Column(ForeignKey('stavy.id'))

    #Vztahy
    stav = relationship('StavModel', back_populates = 'filmy')
    filmZanr = relationship('FilmZanrModel', back_populates = 'film')

#filmy_zanry
class FilmZanrModel(BaseModel):
    __tablename__ = 'filmy_zanry'

    #Atributy
    id = Column(BigInteger, primary_key = True)
    film_id = Column(ForeignKey('filmy.id'))
    zanr_id = Column(ForeignKey('zanry.id'))

    #Vztahy
    film = relationship('FilmModel', back_populates = 'filmZanr')
    zanr = relationship('ZanrModel', back_populates = 'filmZanr')

# %%
#INICIALIZACE STRUKTUR (tabulek) V DATABÁZI
BaseModel.metadata.create_all(engine)

# %%
#SESSION
SessionMaker = sessionmaker(bind = engine)
session = SessionMaker()

#Session management
dbSessionData = {}

def defineStartupAndShutdown(app, SessionMaker):
    @app.on_event("startup")
    async def startup_event():
        session = SessionMaker()
        dbSessionData['session'] = session

    @app.on_event("shutdown")
    def shutdown_event():
        session = dbSessionData.get('session', None)
        if not session is None:
            session.close()

def extractSession(info):
    session = dbSessionData.get('session', None)
    assert not session is None, 'session is not awailable'
    return session

# %%
#CRUD OPS
#Žánr
def crudZanrGet(db: SessionMaker, id: int):
    return db.query(ZanrModel).filter(ZanrModel.id == id).first()

def crudZanrGetAll(db: SessionMaker, skip: int = 0, limit: int = 100):
    return db.query(ZanrModel).offset(skip).limit(limit).all()

def crudZanrCreate(db: SessionMaker, zanr):
    zanrRow = ZanrModel(id = zanr.id, nazev = zanr.nazev)

    db.add(zanrRow)
    db.commit()
    db.refresh(zanrRow)

    return zanrRow

#Stav
def crudStavGet(db: SessionMaker, id: int):
    return db.query(StavModel).filter(StavModel.id == id).first()

def crudStavGetAll(db: SessionMaker, skip: int = 0, limit: int = 100):
    return db.query(StavModel).offset(skip).limit(limit).all()

def crudStavCreate(db: SessionMaker, stav):
    stavRow = StavModel(id = stav.id, nazev = stav.nazev)

    db.add(stavRow)
    db.commit()
    db.refresh(stavRow)

    return stavRow

#Film
def crudFilmGet(db: SessionMaker, id: int):
    return db.query(FilmModel).filter(FilmModel.id == id).first()

def crudFilmGetAll(db: SessionMaker, skip: int = 0, limit: int = 100):
    return db.query(FilmModel).offset(skip).limit(limit).all()

def crudFilmCreate(db: SessionMaker, film):
    filmRow = FilmModel(
        id = film.id,
        nazev = film.nazev,
        rok = film.rok,
        zeme = film.zeme,
        delka = film.delka,
        stav_id = film.stav_id,
    )

    db.add(filmRow)
    db.commit()
    db.refresh(filmRow)

    return filmRow

#filmy_zanry
def crudFilmZanrCreate(db: SessionMaker, fzId, filmId, zanrId):
    fzRow = FilmZanrModel(
        id = fzId,
        film_id = filmId,
        zanr_id = zanrId
    )

    db.add(fzRow)
    db.commit()
    db.refresh(fzRow)

    return fzRow

session.close()

# %%
#ZÁPIS DAT
#Žánr
'''
session = SessionMaker()

zanrData = [line.strip().split(';') for line in (open('ZANR.txt', 'r'))]

for item in zanrData:
    zanrDict = {'id':f'{item[0]}', 'nazev':f'{item[1]}'}
    crudZanrCreate(db = session, zanr = ZanrModel(**zanrDict))

session.close()

#Stav
session = SessionMaker()

stavData = [line.strip().split(';') for line in (open('STAV.txt', 'r'))]

for item in stavData:
    stavDict = {'id':f'{item[0]}', 'nazev':f'{item[1]}'}
    crudStavCreate(db = session, stav = StavModel(**stavDict))

session.close()

#Film
session = SessionMaker()

filmData = [line.strip().split(';') for line in (open('FILM.txt', 'r'))]

for item in filmData:
    filmDict = {
        'id':f'{item[0]}',
        'nazev':f'{item[1]}',
        'rok':f'{item[2]}',
        'zeme':f'{item[3]}',
        'delka':f'{item[4]}',
        'stav_id':f'{item[5]}'
    }
    crudFilmCreate(db = session, film = FilmModel(**filmDict))

session.close()

#filmy_zanry
session = SessionMaker()

fzData = [line.strip().split(';') for line in (open('FjeZ.txt', 'r'))]

for index, item in enumerate(fzData):
    crudFilmZanrCreate(db = session, fzId = index + 1, filmId = item[0], zanrId = item[1])

session.close()
'''
# Out:
# "\nsession = SessionMaker()\n\nzanrData = [line.strip().split(';') for line in (open('ZANR.txt', 'r'))]\n\nfor item in zanrData:\n    zanrDict = {'id':f'{item[0]}', 'nazev':f'{item[1]}'}\n    crudZanrCreate(db = session, zanr = ZanrModel(**zanrDict))\n\nsession.close()\n\n#Stav\nsession = SessionMaker()\n\nstavData = [line.strip().split(';') for line in (open('STAV.txt', 'r'))]\n\nfor item in stavData:\n    stavDict = {'id':f'{item[0]}', 'nazev':f'{item[1]}'}\n    crudStavCreate(db = session, stav = StavModel(**stavDict))\n\nsession.close()\n\n#Film\nsession = SessionMaker()\n\nfilmData = [line.strip().split(';') for line in (open('FILM.txt', 'r'))]\n\nfor item in filmData:\n    filmDict = {\n        'id':f'{item[0]}',\n        'nazev':f'{item[1]}',\n        'rok':f'{item[2]}',\n        'zeme':f'{item[3]}',\n        'delka':f'{item[4]}',\n        'stav_id':f'{item[5]}'\n    }\n    crudFilmCreate(db = session, film = FilmModel(**filmDict))\n\nsession.close()\n\n#filmy_zanry\nsession = SessionMaker()\n\nfzData = [line.strip().split(';') for line in (open('FjeZ.txt', 'r'))]\n\nfor index, item in enumerate(fzData):\n    crudFilmZanrCreate(db = session, fzId = index + 1, filmId = item[0], zanrId = item[1])\n\nsession.close()\n"

# %%
servers = {}
_api_process = None

def start_api(app = None, port = 9992, runNew = True):
    assert port in [9991, 9992, 9993, 9994], f'port has unexpected value {port}'
    def run():
        uvicorn.run(app, port = port, host = '0.0.0.0', root_path = '')    
        
    _api_process = servers.get(port, None)
    if _api_process:
        _api_process.terminate()
        _api_process.join()
        del servers[port]
    
    if runNew:
        assert (not app is None), 'app is None'
        _api_process = Process(target = run, daemon = True)
        _api_process.start()
        servers[port] = _api_process

# %%
#GQL MODELY
#Žánr
class ZanrGQL(graphene.ObjectType):
    id = graphene.ID()
    nazev = graphene.String()

    filmZanr = graphene.List(lambda: FilmZanrGQL)

    def resolve_filmZanr(parent, info):
        return parent.filmZanr

#Film
class FilmGQL(graphene.ObjectType):
    id = graphene.ID()
    nazev = graphene.String()
    rok = graphene.Int()
    zeme = graphene.String()
    delka = graphene.String()

    stav = graphene.Field(lambda: StavGQL)

    def resolve_stav(parent, info):
        return parent.stav

    filmZanr = graphene.List(lambda: FilmZanrGQL)

    def resolve_filmZanr(parent, info):
        return parent.filmZanr

#Stav
class StavGQL(graphene.ObjectType):
    id = graphene.ID()
    nazev = graphene.String()

    filmy = graphene.List(FilmGQL)

    def resolve_filmy(parent, info):
        return parent.filmy    

#filmy_zanry
class FilmZanrGQL(graphene.ObjectType):
    id = graphene.ID()
    film_id = graphene.ID()
    zanr_id = graphene.ID()

    film = graphene.Field(lambda: FilmGQL)

    def resolve_film(parent, info):
        return parent.film

    zanr = graphene.Field(lambda: ZanrGQL)

    def resolve_zanr(parent, info):
        return parent.zanr

# %%
#QUERY ROOT
class QueryGQL(graphene.ObjectType):
    film = graphene.Field(FilmGQL, id = graphene.ID(required = True))
    def resolve_film(root, info, id):
        session = extractSession(info)
        result = session.query(FilmModel).filter(FilmModel.id == id).first()
        return result

    stav = graphene.Field(StavGQL, id = graphene.ID(required = True))
    def resolve_stav(root, info, id):
        session = extractSession(info)
        result = session.query(StavModel).filter(StavModel.id == id).first()
        return result

    zanr = graphene.Field(ZanrGQL, id = graphene.ID(required = True))
    def resolve_zanr(root, info, id):
        session = extractSession(info)
        result = session.query(ZanrModel).filter(ZanrModel.id == id).first()
        return result
    
    filmAll = graphene.List(FilmGQL, id = graphene.ID(required = False))
    def resolve_filmAll(root, info, id):
        session = extractSession(info)
        result = session.query(FilmModel)
        return result
    
    stavAll = graphene.List(StavGQL, id = graphene.ID(required = False))
    def resolve_stavAll(root, info, id):
        session = extractSession(info)
        result = session.query(StavModel)
        return result
    
    zanrAll = graphene.List(ZanrGQL, id = graphene.ID(required = False))
    def resolve_zanrAll(root, info, id):
        session = extractSession(info)
        result = session.query(ZanrModel)
        return result

# %%
#MUTACE
#Film
class CreateFilmInput(graphene.InputObjectType):
    id = graphene.ID(required = False)
    nazev = graphene.String(required = False)
    rok = graphene.Int(required = False)
    zeme = graphene.String(required = False)
    delka = graphene.String(required = False)
    stav_id = graphene.ID(required = False)
    
    def asDict(self):
        return {
            'id': self.id,
            'nazev': self.nazev,
            'rok': self.rok,
            'zeme': self.zeme,
            'delka': self.delka,
            'stav_id': self.stav_id
        }
    
class CreateFilmGQL(graphene.Mutation):
    class Arguments:
        film = CreateFilmInput(required = True)
    
    ok = graphene.Boolean()
    result = graphene.Field(FilmGQL)
    
    def mutate(parent, info, film):
        session = extractSession(info)
        
        filmDict = film.asDict()
        filmRow = FilmModel(**filmDict)
        
        session.add(filmRow)
        session.commit()
        session.refresh(filmRow)
        
        return CreateFilmGQL(ok = True, result = filmRow)
    pass

class UpdateFilmInput(graphene.InputObjectType):
    id = graphene.ID(required = True)
    nazev = graphene.String(required = False)
    rok = graphene.Int(required = False)
    zeme = graphene.String(required = False)
    delka = graphene.String(required = False)
    stav_id = graphene.ID(required = False)
    
    def asDict(self):
        return {
            'id': self.id,
            'nazev': self.nazev,
            'rok': self.rok,
            'zeme': self.zeme,
            'delka': self.delka,
            'stav_id': self.stav_id
        }
    
class UpdateFilmGQL(graphene.Mutation):
    class Arguments:
        film = UpdateFilmInput(required = True)
    
    ok = graphene.Boolean()
    result = graphene.Field(FilmGQL)
    
    def mutate(parent, info, film):
        session = extractSession(info)
        
        filmDict = film.asDict()
        filmRow = session.query(FilmModel).filter(FilmModel.id == film.id).first()
        
        if filmDict['nazev'] != None:
            filmRow.nazev = filmDict['nazev']
        if filmDict['rok'] != None:
            filmRow.rok = filmDict['rok']
        if filmDict['zeme'] != None:
            filmRow.zeme = filmDict['zeme']
        if filmDict['delka'] != None:
            filmRow.delka = filmDict['delka']
        if filmDict['stav_id'] != None:
            filmRow.stav_id = filmDict['stav_id']
        
        session.commit()     
        session.refresh(filmRow)
        
        return CreateFilmGQL(ok = True, result = filmRow)
    pass

class DeleteFilmInput(graphene.InputObjectType):
    id = graphene.ID(required = True)
    nazev = graphene.String(required = False)
    
    def asDict(self):
        return {'id': self.id, 'nazev': self.nazev}

class DeleteFilmGQL(graphene.Mutation):
    class Arguments:
        film = DeleteFilmInput(required = True)

    ok = graphene.Boolean()
    result = graphene.Field(FilmGQL)

    def mutate(parent, info, film):
        session = extractSession(info)
        
        filmDict = film.asDict()
        filmRow = session.query(FilmModel).filter(FilmModel.id == film.id).first()
        
        session.delete(filmRow)
        session.commit()
        
        return CreateFilmGQL(ok = True, result = filmRow)
    pass

#filmy_zanry
class CreateFilmZanrInput(graphene.InputObjectType):
    id = graphene.ID(required = False)
    film_id = graphene.ID(required = False)
    zanr_id = graphene.ID(required = False)
    
    def asDict(self):
        return {
            'id': self.id,
            'film_id': self.film_id,
            'zanr_id': self.zanr_id
        }
    
class CreateFilmZanrGQL(graphene.Mutation):
    class Arguments:
        filmZanr = CreateFilmZanrInput(required = True)
    
    ok = graphene.Boolean()
    result = graphene.Field(FilmZanrGQL)
    
    def mutate(parent, info, filmZanr):
        session = extractSession(info)
        
        filmZanrDict = filmZanr.asDict()
        filmZanrRow = FilmZanrModel(**filmZanrDict)
        
        session.add(filmZanrRow)
        session.commit()
        session.refresh(filmZanrRow)
        
        return CreateFilmZanrGQL(ok = True, result = filmZanrRow)
    pass

class UpdateFilmZanrInput(graphene.InputObjectType):
    id = graphene.ID(required = True)
    film_id = graphene.ID(required = False)
    zanr_id = graphene.ID(required = False)
    
    def asDict(self):
        return {
            'id': self.id,
            'film_id': self.film_id,
            'zanr_id': self.zanr_id
        }
    
class UpdateFilmZanrGQL(graphene.Mutation):
    class Arguments:
        filmZanr = UpdateFilmZanrInput(required = True)
    
    ok = graphene.Boolean()
    result = graphene.Field(FilmZanrGQL)
    
    def mutate(parent, info, filmZanr):
        session = extractSession(info)
        
        filmZanrDict = filmZanr.asDict()
        filmZanrRow = session.query(FilmZanrModel).filter(FilmZanrModel.id == filmZanr.id).first()
        
        if filmZanrDict['film_id'] != None:
            filmZanrRow.film_id = filmZanrDict['film_id']
        if filmZanrDict['zanr_id'] != None:
            filmZanrRow.zanr_id = filmZanrDict['zanr_id']
        
        session.commit()     
        session.refresh(filmZanrRow)
        
        return CreateFilmZanrGQL(ok = True, result = filmZanrRow)
    pass

class DeleteFilmZanrInput(graphene.InputObjectType):
    id = graphene.ID(required = True)
    
    def asDict(self):
        return {'id': self.id}

class DeleteFilmZanrGQL(graphene.Mutation):
    class Arguments:
        filmZanr = DeleteFilmZanrInput(required = True)

    ok = graphene.Boolean()
    result = graphene.Field(FilmZanrGQL)

    def mutate(parent, info, filmZanr):
        session = extractSession(info)
        
        filmZanrDict = filmZanr.asDict()
        filmZanrRow = session.query(FilmZanrModel).filter(FilmZanrModel.id == filmZanr.id).first()
        
        session.delete(filmZanrRow)
        session.commit()
        
        return CreateFilmZanrGQL(ok = True, result = filmZanrRow)
    pass

# %%
class Mutations(graphene.ObjectType):
    #Film
    create_film = CreateFilmGQL.Field()
    update_film = UpdateFilmGQL.Field()
    delete_film = DeleteFilmGQL.Field()
    
    #filmy_zanry
    create_filmZanr = CreateFilmZanrGQL.Field()
    update_filmZanr = UpdateFilmZanrGQL.Field()
    delete_filmZanr = DeleteFilmZanrGQL.Field()

# %%
#ZAPNUTÍ SERVERU
graphql_app = GraphQLApp(
    schema = graphene.Schema(query = QueryGQL, mutation =Mutations), 
    on_get=make_graphiql_handler())

app = FastAPI()#root_path='/api')

origins = [
    "http://localhost",
    "http://localhost:8080",
    "http://localhost:8000",
    "http://localhost:31102",
    "null",
]

app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

defineStartupAndShutdown(app, SessionMaker)

app.add_route('/gql/', graphql_app)
start_api(app = app, port = 9992, runNew = True)
# Out:
# INFO:     Started server process [138]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9992 (Press CTRL+C to quit)
# INFO:     172.18.0.1:50472 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50472 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50612 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50612 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50672 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50672 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50678 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50678 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50776 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50776 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50782 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50782 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50816 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50816 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50822 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50822 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50836 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50836 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50870 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50886 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50902 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50906 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50902 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50914 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50944 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50942 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50944 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50954 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50972 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50976 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50972 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:50986 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51004 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51002 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51004 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51002 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51086 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51084 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51084 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51086 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51094 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51098 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51094 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51112 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51138 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51142 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51138 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51150 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51200 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51204 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51200 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51212 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51400 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51398 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51398 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51400 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:51438 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# An exception occurred in resolvers
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1819, in _execute_context
#     self.dialect.do_execute(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 732, in do_execute
#     cursor.execute(statement, parameters)
# psycopg2.errors.UniqueViolation: duplicate key value violates unique constraint "filmy_pkey"
# DETAIL:  Key (id)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/graphql/execution/execute.py", line 617, in resolve_field
#     result = resolve_fn(source, info, **args)
#   File "/tmp/ipykernel_97/643185560.py", line 35, in mutate
#     session.commit()
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 1431, in commit
#     self._transaction.commit(_to_root=self.future)
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 829, in commit
#     self._prepare_impl()
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 808, in _prepare_impl
#     self.session.flush()
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 3363, in flush
#     self._flush(objects)
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 3503, in _flush
#     transaction.rollback(_capture_exception=True)
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 3463, in _flush
#     flush_context.execute()
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/unitofwork.py", line 456, in execute
#     rec.execute(self)
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/unitofwork.py", line 630, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/persistence.py", line 245, in save_obj
#     _emit_insert_statements(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/persistence.py", line 1238, in _emit_insert_statements
#     result = connection._execute_20(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1631, in _execute_20
#     return meth(self, args_10style, kwargs_10style, execution_options)
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/sql/elements.py", line 325, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1498, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1862, in _execute_context
#     self._handle_dbapi_exception(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 2043, in _handle_dbapi_exception
#     util.raise_(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/base.py", line 1819, in _execute_context
#     self.dialect.do_execute(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/engine/default.py", line 732, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "filmy_pkey"
# DETAIL:  Key (id)=(1) already exists.
#
# [SQL: INSERT INTO filmy (nazev, rok, zeme, delka, stav_id) VALUES (%(nazev)s, %(rok)s, %(zeme)s, %(delka)s, %(stav_id)s) RETURNING filmy.id]
# [parameters: {'nazev': 'Top Gun', 'rok': 2022, 'zeme': 'USA', 'delka': '', 'stav_id': None}]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# INFO:     172.18.0.1:51438 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [138]

# %%
#VYPNUTÍ SERVERU
start_api(app = app, port = 9992, runNew = False)
start_api(app = app, port = 9992, runNew = True)
# Out:
# INFO:     Started server process [3274]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:9992 (Press CTRL+C to quit)
# INFO:     172.18.0.1:52002 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52024 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52042 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52040 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52042 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52040 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52156 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52156 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52162 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52172 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52162 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52178 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52188 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52188 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52194 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52188 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52188 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52194 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52204 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52208 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52228 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52232 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52228 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52240 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52250 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52250 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52256 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52250 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52250 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52256 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52312 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52312 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52318 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52328 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52318 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52334 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52354 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52362 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52362 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52354 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52354 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52362 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52362 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52394 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52350 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52400 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52410 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52410 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52418 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52410 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52424 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52436 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52436 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52442 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52436 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52450 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52466 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52466 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52472 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52466 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52472 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52482 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52510 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52514 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52510 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52522 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52530 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52534 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52530 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52542 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52606 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52608 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52606 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52608 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52618 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52622 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52618 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52636 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52618 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52642 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52652 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52656 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52652 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52664 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52674 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52674 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52680 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52674 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52674 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52680 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52690 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52694 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52690 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52708 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52690 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52714 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52724 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52724 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52724 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52730 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52724 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52730 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52770 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52770 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52778 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52770 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52784 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52770 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52784 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52778 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52784 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52778 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52784 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52770 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52778 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52824 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52824 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52820 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52810 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52842 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52850 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52850 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52858 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52850 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52864 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52850 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52864 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52858 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52864 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52882 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52882 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52890 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52882 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52896 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52906 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52910 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52906 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52918 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52942 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52948 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52942 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52948 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52956 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52964 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52968 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52964 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52976 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52986 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52986 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52994 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:52986 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53000 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53008 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53016 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53020 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53016 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53028 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53054 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53054 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53062 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53054 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53068 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53054 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53068 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53062 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53054 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53100 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53102 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53102 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53100 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53100 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53102 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53110 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53100 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53114 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53114 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53138 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53146 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53138 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53150 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53162 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53162 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53170 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53162 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53176 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53188 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53192 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53188 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53200 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53208 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53208 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53216 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53208 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53222 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53266 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53266 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53274 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53266 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53280 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53290 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53290 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53298 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53290 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53304 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53322 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53322 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53330 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53322 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53336 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53348 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53348 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53356 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53348 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53362 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53374 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53378 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53378 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53374 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53386 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53390 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53386 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53412 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53386 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53418 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53418 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53386 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53412 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53418 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53436 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53436 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53444 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53436 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53450 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53460 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53460 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53460 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53466 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53460 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53476 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53484 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53484 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53484 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53490 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53484 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53502 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53522 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53522 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53528 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53538 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53528 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53544 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53554 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53558 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53554 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53566 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53574 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53574 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53574 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53580 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53574 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53592 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53606 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53606 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53612 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# An exception occurred in resolvers
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2637, in delete
#     state = attributes.instance_state(instance)
# AttributeError: 'NoneType' object has no attribute '_sa_instance_state'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.9/site-packages/graphql/execution/execute.py", line 617, in resolve_field
#     result = resolve_fn(source, info, **args)
#   File "/tmp/ipykernel_97/643185560.py", line 109, in mutate
#     session.delete(filmRow)
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/orm/session.py", line 2639, in delete
#     util.raise_(
#   File "/opt/conda/lib/python3.9/site-packages/sqlalchemy/util/compat.py", line 207, in raise_
#     raise exception
# sqlalchemy.orm.exc.UnmappedInstanceError: Class 'builtins.NoneType' is not mapped
# INFO:     172.18.0.1:53612 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53630 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53642 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53630 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53648 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53658 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53658 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53658 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53664 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53658 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53674 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53682 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53682 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53682 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53688 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53682 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53700 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53708 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53708 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53708 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53714 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53708 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53724 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53736 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53736 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53736 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53742 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53736 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53752 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53762 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53762 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53762 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53768 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53762 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53778 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53790 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53790 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53790 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53796 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53790 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53806 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53814 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53814 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53814 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53820 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53814 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53830 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53858 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53856 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53858 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53866 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53902 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53906 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53902 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53914 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53930 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53936 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53930 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53942 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53956 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53952 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53956 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53964 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53988 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53986 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53988 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:53996 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54006 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54010 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54006 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54018 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54034 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54038 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54034 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54046 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54056 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54056 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54062 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54056 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54062 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54056 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54094 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54098 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54094 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54106 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54116 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54120 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54116 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54128 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54136 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54140 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54136 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54148 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54158 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54162 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54158 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54170 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54186 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54190 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54186 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54198 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54212 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54210 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54212 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54210 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54242 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54246 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54242 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54254 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54268 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54272 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54268 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54280 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54294 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54298 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54294 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54306 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54318 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54322 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54318 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54330 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54340 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54344 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54340 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54352 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54362 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54366 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54362 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54374 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54384 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54388 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54384 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54396 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54408 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54412 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54408 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54420 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54428 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54432 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54428 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54440 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54450 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54454 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54450 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54462 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54450 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54462 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54450 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54454 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54480 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54484 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54480 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54492 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54502 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54506 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54502 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54514 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54514 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54502 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54506 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54514 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54534 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54538 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54534 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54546 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54554 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54558 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54554 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54566 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54588 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54592 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54588 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54600 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54612 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54614 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54614 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54612 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54622 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54626 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54622 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54640 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54652 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54656 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54652 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54664 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54678 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54682 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54678 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54690 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54700 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54704 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54700 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54712 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54728 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54732 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54728 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54740 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54750 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54754 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54750 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54762 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54774 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54778 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54774 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54786 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54798 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54802 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54798 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54810 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54822 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54824 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54822 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54824 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54858 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54862 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54858 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:54862 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55670 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55674 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55670 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55674 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55682 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55686 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55682 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55704 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55716 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55720 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55716 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55728 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55740 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55740 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55752 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55740 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55810 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55808 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55810 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55808 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55818 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55822 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55818 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55840 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55980 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55984 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55980 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:55992 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56014 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56016 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56014 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56016 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56038 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56042 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56038 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56048 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56064 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56068 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56064 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56076 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56134 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56134 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56146 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56134 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56212 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56216 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56212 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56224 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56294 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56298 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56294 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56308 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56362 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56366 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56362 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56376 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56390 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56394 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56390 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56402 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56418 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56422 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56418 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56428 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56444 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56444 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56450 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56444 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56476 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56478 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56476 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56478 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56518 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56520 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56518 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56528 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56576 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56574 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56574 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56576 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56588 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56584 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56588 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56584 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56606 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56610 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56606 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56626 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56636 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56636 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56646 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56636 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56652 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56662 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56652 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56668 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56678 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56678 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56688 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56678 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56710 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56710 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56714 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56710 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56744 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56748 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56744 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56756 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56766 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56772 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56766 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56778 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56794 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56790 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56794 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56790 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56802 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56806 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56802 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56820 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56830 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56830 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56842 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56830 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56838 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56854 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56838 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56860 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56874 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56878 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56874 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56886 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56896 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56896 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56906 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56896 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56904 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56920 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56904 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56926 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56978 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56982 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56978 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:56990 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57002 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57006 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57002 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57014 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57046 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57048 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57046 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57056 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57068 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57072 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57068 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57082 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57092 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57096 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57092 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57104 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57128 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57132 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57128 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57140 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57150 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57150 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57154 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57160 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57174 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57178 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57174 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57186 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57202 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57204 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57202 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57204 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57212 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57216 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57212 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57234 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57244 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57248 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57244 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57256 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57266 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57272 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57266 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57278 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57292 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57296 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57292 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57304 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57316 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57320 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57316 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57328 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57338 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57340 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57338 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57340 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57348 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57352 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57348 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57366 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57380 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57384 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57380 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57392 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57414 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57412 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57412 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57414 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57422 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57426 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57422 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57426 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57444 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57442 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57444 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57458 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57594 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57592 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57594 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57592 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57602 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57606 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57602 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57620 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57748 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57750 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57750 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57748 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57804 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57802 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57804 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57814 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57814 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57804 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57814 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57828 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57864 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57866 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57864 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57874 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57874 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57864 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57892 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57896 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57892 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57904 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57904 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57892 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57918 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57922 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57918 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57930 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57930 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57918 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57990 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57994 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57990 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58002 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58002 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:57990 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58020 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58024 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58020 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58032 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58032 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58020 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58046 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58050 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58046 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58058 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58058 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58046 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58376 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58378 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58376 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58378 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58388 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58392 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58422 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58422 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58428 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58422 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58454 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58454 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58482 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58566 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58608 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58610 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58608 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58610 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58630 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58630 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58644 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58648 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58644 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58656 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58656 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58644 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58696 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58700 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58696 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58708 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58708 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58696 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58728 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58732 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58728 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58740 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58740 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58728 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58758 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58762 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58762 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58758 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58762 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58758 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58820 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58824 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58820 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58830 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58830 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58820 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58928 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58932 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58928 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58940 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58928 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58940 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58932 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:58940 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59008 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59008 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59012 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59008 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59008 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59012 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59016 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59008 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59042 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59038 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59042 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59052 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59064 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59068 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59064 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59076 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59086 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59090 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59086 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59100 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59116 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59120 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59116 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59128 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59146 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59146 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59156 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59146 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59154 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59168 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59154 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59174 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59174 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59154 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59168 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59174 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59192 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59196 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59192 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59204 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59216 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59220 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59216 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59228 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59236 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59240 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59236 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59248 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59272 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59276 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59272 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59284 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59284 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59272 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59276 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59284 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59302 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59302 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59308 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59312 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59342 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59346 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59342 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59354 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59366 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59370 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59366 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59378 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59418 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59418 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59424 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59428 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59424 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59428 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59474 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59478 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59474 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59486 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59502 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59508 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59502 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59514 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59514 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59502 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59508 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59514 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59534 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59534 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59544 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59534 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59540 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59556 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59540 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59562 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59570 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59574 - "OPTIONS /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59570 - "POST /gql/ HTTP/1.1" 200 OK
# INFO:     172.18.0.1:59584 - "POST /gql/ HTTP/1.1" 200 OK

# %%
start_api(app = app, port = 9992, runNew = False)
